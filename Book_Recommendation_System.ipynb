# %% [markdown]
# # Book Recommendation System using cluster

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Books.csv')
df.head(1)
# Out:
#          ISBN           Book-Title         Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford                2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %%
df.shape
# Out:
# (271360, 8)

# %%
df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
df = df[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher','Image-URL-L']]
df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
df.rename(columns={'Book-Title':'Title','Book-Author':'Author','Year-Of-Publication':'Year','Image-URL-L':'Image-URL'},inplace=True)

# %%
df.head(2)
# Out:
#          ISBN                Title                Author  Year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford  2002
# 1  0002005018         Clara Callan  Richard Bruce Wright  2001
#
#                  Publisher                                          Image-URL
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
users = pd.read_csv('Users.csv')
users.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
users['Age'] = users['Age'].fillna(users.Age.mean()).astype('int')
users.head(2)
# Out:
#    User-ID                   Location  Age
# 0        1         nyc, new york, usa   34
# 1        2  stockton, california, usa   18

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings = pd.read_csv('Ratings.csv')
ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
ratings['User-ID'].value_counts()
# Out:
# User-ID
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
ratings['User-ID'].unique().shape
# Out:
# (105283,)

# %%
x=ratings['User-ID'].value_counts()>200

# %%
x[x].shape
# Out:
# (899,)

# %%
y=x[x].index
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='User-ID', length=899)

# %%
ratings=ratings[ratings['User-ID'].isin(y)]

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
data = df.merge(ratings,on='ISBN')
data.head()
# Out:
#          ISBN                                              Title  \
# 0  0002005018                                       Clara Callan
# 1  0002005018                                       Clara Callan
# 2  0002005018                                       Clara Callan
# 3  0002005018                                       Clara Callan
# 4  0374157065  Flu: The Story of the Great Influenza Pandemic...
#
#                  Author  Year              Publisher  \
# 0  Richard Bruce Wright  2001  HarperFlamingo Canada
# 1  Richard Bruce Wright  2001  HarperFlamingo Canada
# 2  Richard Bruce Wright  2001  HarperFlamingo Canada
# 3  Richard Bruce Wright  2001  HarperFlamingo Canada
# 4      Gina Bari Kolata  1999   Farrar Straus Giroux
#
#                                            Image-URL  User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/0002005018.0...    11676            8
# 1  http://images.amazon.com/images/P/0002005018.0...    85526            0
# 2  http://images.amazon.com/images/P/0002005018.0...    96054            0
# 3  http://images.amazon.com/images/P/0002005018.0...   177458            0
# 4  http://images.amazon.com/images/P/0374157065.0...   110912           10

# %%
num_rating = data.groupby('Title')['Book-Rating'].count().reset_index()
num_rating.shape
# Out:
# (160269, 2)

# %%
num_rating.rename(columns={'Book-Rating':'num_of_rating'},inplace=True)

# %%
final_rating = data.merge(num_rating,on='Title')
print(final_rating.shape)
final_rating.head()
# Out:
# (487671, 9)
#          ISBN                                              Title  \
# 0  0002005018                                       Clara Callan
# 1  0002005018                                       Clara Callan
# 2  0002005018                                       Clara Callan
# 3  0002005018                                       Clara Callan
# 4  0374157065  Flu: The Story of the Great Influenza Pandemic...
#
#                  Author  Year              Publisher  \
# 0  Richard Bruce Wright  2001  HarperFlamingo Canada
# 1  Richard Bruce Wright  2001  HarperFlamingo Canada
# 2  Richard Bruce Wright  2001  HarperFlamingo Canada
# 3  Richard Bruce Wright  2001  HarperFlamingo Canada
# 4      Gina Bari Kolata  1999   Farrar Straus Giroux
#
#                                            Image-URL  User-ID  Book-Rating  \
# 0  http://images.amazon.com/images/P/0002005018.0...    11676            8
# 1  http://images.amazon.com/images/P/0002005018.0...    85526            0
# 2  http://images.amazon.com/images/P/0002005018.0...    96054            0
# 3  http://images.amazon.com/images/P/0002005018.0...   177458            0
# 4  http://images.amazon.com/images/P/0374157065.0...   110912           10
#
#    num_of_rating
# 0              4
# 1              4
# 2              4
# 3              4
# 4              3

# %%
final_rating = final_rating[final_rating['num_of_rating']>=50]
final_rating
# Out:
#               ISBN                            Title           Author  Year  \
# 7       0399135782           The Kitchen God's Wife          Amy Tan  1991
# 8       0399135782           The Kitchen God's Wife          Amy Tan  1991
# 9       0399135782           The Kitchen God's Wife          Amy Tan  1991
# 10      0399135782           The Kitchen God's Wife          Amy Tan  1991
# 11      0399135782           The Kitchen God's Wife          Amy Tan  1991
# ...            ...                              ...              ...   ...
# 486552  1878702831                           Echoes      Nancy Morse  1992
# 486653  0394429869  I Know Why the Caged Bird Sings     Maya Angelou  1996
# 486655  0449001164                      The Promise      CHAIM POTOK  1997
# 486788  0743527631         The Pillars of the Earth      Ken Follett  2002
# 486790  0745168086              The Handmaid's Tale  Margaret Atwood  1999
#
#                             Publisher  \
# 7                    Putnam Pub Group
# 8                    Putnam Pub Group
# 9                    Putnam Pub Group
# 10                   Putnam Pub Group
# 11                   Putnam Pub Group
# ...                               ...
# 486552  Meteor Publishing Corporation
# 486653                   Random House
# 486655               Ballantine Books
# 486788                         Encore
# 486790            Chivers Audio Books
#
#                                                 Image-URL  User-ID  \
# 7       http://images.amazon.com/images/P/0399135782.0...    11676
# 8       http://images.amazon.com/images/P/0399135782.0...    36836
# 9       http://images.amazon.com/images/P/0399135782.0...    46398
# 10      http://images.amazon.com/images/P/0399135782.0...   113270
# 11      http://images.amazon.com/images/P/0399135782.0...   113519
# ...                                                   ...      ...
# 486552  http://images.amazon.com/images/P/1878702831.0...   238781
# 486653  http://images.amazon.com/images/P/0394429869.0...   239594
# 486655  http://images.amazon.com/images/P/0449001164.0...   239594
# 486788  http://images.amazon.com/images/P/0743527631.0...   240144
# 486790  http://images.amazon.com/images/P/0745168086.0...   240144
#
#         Book-Rating  num_of_rating
# 7                 9            111
# 8                 0            111
# 9                 9            111
# 10                0            111
# 11                0            111
# ...             ...            ...
# 486552            0             54
# 486653            8             82
# 486655            7             62
# 486788            0             85
# 486790            0            130
#
# [61853 rows x 9 columns]

# %%
final_rating.sample(5)
# Out:
#              ISBN                                              Title  \
# 20552  0380789019                                         Neverwhere
# 16345  0440211727                                     A Time to Kill
# 40505  0743412028                                     Pay It Forward
# 59989  0515119784                                    Range of Motion
# 48180  0140119906  Love in the Time of Cholera (Penguin Great Boo...
#
#                        Author  Year      Publisher  \
# 20552             Neil Gaiman  1998           Avon
# 16345            JOHN GRISHAM  1992           Dell
# 40505     Catherine Ryan Hyde  2000         Pocket
# 59989          Elizabeth Berg  1996     Jove Books
# 48180  Gabriel Garcia Marquez  1994  Penguin Books
#
#                                                Image-URL  User-ID  \
# 20552  http://images.amazon.com/images/P/0380789019.0...   157273
# 16345  http://images.amazon.com/images/P/0440211727.0...   187517
# 40505  http://images.amazon.com/images/P/0743412028.0...   175003
# 59989  http://images.amazon.com/images/P/0515119784.0...   222296
# 48180  http://images.amazon.com/images/P/0140119906.0...   204864
#
#        Book-Rating  num_of_rating
# 20552            0             72
# 16345            0            210
# 40505            0             70
# 59989            0             54
# 48180           10             62

# %%
final_rating.drop_duplicates(['User-ID','Title'],inplace=True)

# %%
final_rating.shape
# Out:
# (59850, 9)

# %%
book_pivot = final_rating.pivot_table(columns='User-ID',index='Title',values='Book-Rating')
book_pivot.head()
# Out:
# User-ID                254     2276    2766    2977    3363    3757    4017    \
# Title
# 1984                      9.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1st to Die: A Novel       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2nd Chance                NaN    10.0     NaN     NaN     NaN     NaN     NaN
# 4 Blondes                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 84 Charing Cross Road     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# User-ID                4385    6242    6251    ...  274004  274061  274301  \
# Title                                          ...
# 1984                      NaN     NaN     NaN  ...     NaN     NaN     NaN
# 1st to Die: A Novel       NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2nd Chance                NaN     NaN     NaN  ...     NaN     NaN     NaN
# 4 Blondes                 NaN     NaN     0.0  ...     NaN     NaN     NaN
# 84 Charing Cross Road     NaN     NaN     NaN  ...     NaN     NaN     NaN
#
# User-ID                274308  274808  275970  277427  277478  277639  278418
# Title
# 1984                      NaN     NaN     0.0     NaN     NaN     NaN     NaN
# 1st to Die: A Novel       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2nd Chance                0.0     NaN     NaN     NaN     NaN     0.0     NaN
# 4 Blondes                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 84 Charing Cross Road     NaN     NaN    10.0     NaN     NaN     NaN     NaN
#
# [5 rows x 888 columns]

# %%
book_pivot.fillna(0,inplace=True)
book_pivot
# Out:
# User-ID                                             254     2276    2766    \
# Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    3757    \
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4017    4385    6242    \
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     7.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6251    ...  274004  \
# Title                                                       ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# 84 Charing Cross Road                                  0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             274061  274301  274308  \
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     8.0     0.0
#
# User-ID                                             274808  275970  277427  \
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0    10.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             277478  277639  278418
# Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [742 rows x 888 columns]

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)
book_sparse
# Out:
# <742x888 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14940 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=5)

# %%
distance
# Out:
# array([[ 0.        , 69.5413546 , 69.69935437, 72.74613392, 76.83098333]])

# %%
suggestion
# Out:
# array([[237, 238, 240, 241, 184]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive'],
#       dtype='object', name='Title')

# %%
book_pivot.index[3]
# Out:
# '4 Blondes'

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[3,:].values.reshape(1,-1),n_neighbors=5)

# %%
distance
# Out:
# array([[ 0.        , 22.93468988, 23.        , 24.08318916, 24.33105012]])

# %%
suggestion
# Out:
# array([[  3, 372, 393, 320, 184]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['4 Blondes', 'No Safe Place', 'Pleading Guilty', 'Long After Midnight',
#        'Exclusive'],
#       dtype='object', name='Title')

# %%
books_name = book_pivot.index

# %%
books_name
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Title', length=742)

# %%
import pickle

# %%
pickle.dump(model,open('model.pkl','wb'))
pickle.dump(books_name,open('books_name.pkl','wb'))
pickle.dump(final_rating,open('final_rating.pkl','wb'))
pickle.dump(book_pivot,open('book_pivot.pkl','wb'))

# %%
def recommend_book(book_name):
    book_id=np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=5)
    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
    for j in books:
        print(j)

# %%
recommend_book('A Bend in the Road')
# Out:
# A Bend in the Road
# Exclusive
# No Safe Place
# Family Album
# Lake Wobegon days
